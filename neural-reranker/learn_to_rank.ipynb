# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# !pip3 install xgboost
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.11/dist-packages (2.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from xgboost) (2.0.2)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.11/dist-packages (from xgboost) (2.21.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from xgboost) (1.15.3)

# %%
# !pip3 install rank-bm25
# Out:
# Collecting rank-bm25
#   Downloading rank_bm25-0.2.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from rank-bm25) (2.0.2)
# Downloading rank_bm25-0.2.2-py3-none-any.whl (8.6 kB)
# Installing collected packages: rank-bm25
# Successfully installed rank-bm25-0.2.2

# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer, util
from rank_bm25 import BM25Okapi
from tqdm import tqdm
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import torch
import os
from collections import Counter

# Set tokenizer parallelism to false to avoid deadlocks
os.environ["TOKENIZERS_PARALLELISM"] = "false"

def prepare_features(df_collection, df_query, sbert_model, bm25, top_k=200):
    # Get document texts
    doc_texts = df_collection["full_text"].tolist()
    doc_uids = df_collection["cord_uid"].tolist()

    # Get SBERT embeddings
    print("Encoding with SBERT")
    doc_embeds = sbert_model.encode(doc_texts, convert_to_tensor=True, show_progress_bar=True)
    query_embeds = sbert_model.encode(df_query["tweet_text"].tolist(), convert_to_tensor=True, show_progress_bar=True)

    # Prepare features
    features = []
    labels = []
    query_ids = []
    doc_ids = []

    print("Generating features")
    for i, qvec in enumerate(tqdm(query_embeds)):
        query = df_query["tweet_text"].iloc[i]
        true_doc_id = df_query["cord_uid"].iloc[i]

        # Get SBERT scores for all documents
        sbert_scores = util.cos_sim(qvec, doc_embeds)[0].cpu().numpy()

        # Get BM25 scores
        bm25_scores = bm25.get_scores(query.split())

        # Get top-k candidates based on SBERT scores
        top_k_indices = np.argsort(sbert_scores)[-top_k:][::-1]

        # Combine features for top-k candidates
        for idx in top_k_indices:
            doc_text = doc_texts[idx]

            # Basic text features
            query_words = set(query.lower().split())
            doc_words = set(doc_text.lower().split())

            # Word overlap features
            word_overlap = len(query_words.intersection(doc_words))
            word_overlap_ratio = word_overlap / len(query_words) if len(query_words) > 0 else 0

            # Length features
            query_length = len(query.split())
            doc_length = len(doc_text.split())
            length_ratio = min(query_length, doc_length) / max(query_length, doc_length)

            # Combine all features
            feature_vector = [
                sbert_scores[idx],  # SBERT similarity
                bm25_scores[idx],   # BM25 score
                word_overlap,       # Number of overlapping words
                word_overlap_ratio, # Ratio of overlapping words
                query_length,       # Query length
                doc_length,         # Document length
                length_ratio,       # Length ratio
            ]

            features.append(feature_vector)
            labels.append(1 if doc_uids[idx] == true_doc_id else 0)
            query_ids.append(df_query["post_id"].iloc[i])
            doc_ids.append(doc_uids[idx])

    return np.array(features), np.array(labels), query_ids, doc_ids

def get_group_sizes(query_ids):
    return [count for _, count in sorted(Counter(query_ids).items())]

def train_ltr_model(X, y, query_ids, params=None):
    """Train XGBoost LTR model"""
    if params is None:
        params = {
            'objective': 'rank:pairwise',
            'learning_rate': 0.01,  # Further reduced learning rate
            'max_depth': 8,         # Increased depth
            'min_child_weight': 1,
            'subsample': 0.8,
            'colsample_bytree': 0.8,
            'tree_method': 'hist',
            'random_state': 42,
            'eval_metric': ['map@5', 'ndcg@5'],  # Changed to MAP@5 for better MRR alignment
            'max_leaves': 128,      # Increased max leaves
            'grow_policy': 'lossguide',
            'scale_pos_weight': 10  # Added to handle class imbalance
        }

    # Compute group sizes
    train_group_sizes = get_group_sizes(query_ids)

    # Prepare DMatrix
    dtrain = xgb.DMatrix(X, label=y)
    dtrain.set_group(train_group_sizes)

    # Train model with more rounds and better early stopping
    model = xgb.train(
        params,
        dtrain,
        num_boost_round=500,  # Increased number of rounds
        evals=[(dtrain, 'train')],
        early_stopping_rounds=50,  # Increased early stopping rounds
        verbose_eval=True
    )

    # Print feature importance
    importance = model.get_score(importance_type='gain')
    print("\nFeature Importance:")
    for feat, imp in sorted(importance.items(), key=lambda x: x[1], reverse=True):
        print(f"{feat}: {imp:.4f}")

    return model

def main():
    # Load data
    print("Loading data...")
    df_collection = pd.read_pickle("subtask4b_collection_data.pkl")
    df_query = pd.read_csv("subtask4b_query_tweets_train.tsv", sep="\t")

    # Prepare document texts
    print("Preparing document texts...")
    df_collection["full_text"] = df_collection["title"].fillna('') + " " + df_collection["abstract"].fillna('')

    # Initialize models
    print("Initializing models...")
    sbert_model = SentenceTransformer("/content/drive/MyDrive/Colab Notebooks/fine-tuned-multi-qa-MiniLM-L6-cos-v1")
    tokenized_corpus = [doc.split() for doc in df_collection["full_text"]]
    bm25 = BM25Okapi(tokenized_corpus)

    # Prepare features
    X, y, query_ids, doc_ids = prepare_features(
        df_collection,
        df_query,
        sbert_model,
        bm25,
        top_k=200  # Increased top_k for better coverage
    )

    # Convert query_ids to numpy array for indexing
    query_ids = np.array(query_ids)

    # Normalize features
    scaler = MinMaxScaler()
    X = scaler.fit_transform(X)

    # Split data while preserving query groups
    unique_queries = np.unique(query_ids)
    train_queries = np.random.choice(unique_queries, size=int(0.8 * len(unique_queries)), replace=False)
    train_mask = np.isin(query_ids, train_queries)

    X_train, y_train, q_train = X[train_mask], y[train_mask], query_ids[train_mask]
    X_val, y_val, q_val = X[~train_mask], y[~train_mask], query_ids[~train_mask]

    # Train model
    print("Training LTR model...")
    model = train_ltr_model(X_train, y_train, q_train)

    # Save model and scaler
    model.save_model("ltr_model.json")
    np.save("feature_scaler.npy", scaler)

    # Evaluate on validation set
    val_group_sizes = get_group_sizes(q_val)
    dval = xgb.DMatrix(X_val, label=y_val)
    dval.set_group(val_group_sizes)
    val_preds = model.predict(dval)

    # Calculate MRR@5
    def mrr_at_k(predictions, labels, query_ids, k=5):
        df = pd.DataFrame({
            'query_id': query_ids,
            'pred': predictions,
            'label': labels
        })

        mrr = 0
        total_queries = 0
        for qid in df['query_id'].unique():
            q_df = df[df['query_id'] == qid].sort_values('pred', ascending=False)
            if q_df['label'].sum() > 0:  # Only count queries with relevant documents
                total_queries += 1
                for i, (_, row) in enumerate(q_df.iterrows()):
                    if row['label'] == 1:
                        mrr += 1 / (i + 1)
                        break
        return mrr / total_queries if total_queries > 0 else 0

    mrr_score = mrr_at_k(val_preds, y_val, q_val)
    print(f"\nValidation MRR@5: {mrr_score:.4f}")

    # Print some statistics
    print("\nValidation Statistics:")
    print(f"Total validation queries: {len(np.unique(q_val))}")
    print(f"Queries with relevant documents: {sum(1 for qid in np.unique(q_val) if y_val[q_val == qid].sum() > 0)}")
    print(f"Average relevant documents per query: {y_val.sum() / len(np.unique(q_val)):.2f}")

if __name__ == "__main__":
    main()
# Out:
# Loading data...
# Preparing document texts...
# Initializing models...
# Encoding with SBERT
# Batches:   0%|          | 0/242 [00:00<?, ?it/s]
# Batches:   0%|          | 0/402 [00:00<?, ?it/s]
# Generating features
# 100%|██████████| 12853/12853 [20:46<00:00, 10.31it/s]
# Training LTR model...
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [13:07:52] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [0]	train-map@5:0.68802	train-ndcg@5:0.71628
# [1]	train-map@5:0.70614	train-ndcg@5:0.73183
# [2]	train-map@5:0.72219	train-ndcg@5:0.74799
# [3]	train-map@5:0.72825	train-ndcg@5:0.75336
# [4]	train-map@5:0.73024	train-ndcg@5:0.75529
# [5]	train-map@5:0.73260	train-ndcg@5:0.75702
# [6]	train-map@5:0.73103	train-ndcg@5:0.75540
# [7]	train-map@5:0.73497	train-ndcg@5:0.75892
# [8]	train-map@5:0.73686	train-ndcg@5:0.76061
# [9]	train-map@5:0.73749	train-ndcg@5:0.76138
# [10]	train-map@5:0.73735	train-ndcg@5:0.76140
# [11]	train-map@5:0.73829	train-ndcg@5:0.76236
# [12]	train-map@5:0.73868	train-ndcg@5:0.76286
# [13]	train-map@5:0.73932	train-ndcg@5:0.76326
# [14]	train-map@5:0.73982	train-ndcg@5:0.76383
# [15]	train-map@5:0.73895	train-ndcg@5:0.76280
# [16]	train-map@5:0.73882	train-ndcg@5:0.76255
# [17]	train-map@5:0.73965	train-ndcg@5:0.76314
# [18]	train-map@5:0.74101	train-ndcg@5:0.76450
# [19]	train-map@5:0.74101	train-ndcg@5:0.76461
# [20]	train-map@5:0.74093	train-ndcg@5:0.76469
# [21]	train-map@5:0.74123	train-ndcg@5:0.76494
# [22]	train-map@5:0.74095	train-ndcg@5:0.76471
# [23]	train-map@5:0.74159	train-ndcg@5:0.76527
# [24]	train-map@5:0.74209	train-ndcg@5:0.76566
# [25]	train-map@5:0.74238	train-ndcg@5:0.76603
# [26]	train-map@5:0.74313	train-ndcg@5:0.76668
# [27]	train-map@5:0.74272	train-ndcg@5:0.76635
# [28]	train-map@5:0.74249	train-ndcg@5:0.76619
# [29]	train-map@5:0.74279	train-ndcg@5:0.76653
# [30]	train-map@5:0.74291	train-ndcg@5:0.76657
# [31]	train-map@5:0.74344	train-ndcg@5:0.76704
# [32]	train-map@5:0.74340	train-ndcg@5:0.76707
# [33]	train-map@5:0.74381	train-ndcg@5:0.76737
# [34]	train-map@5:0.74379	train-ndcg@5:0.76728
# [35]	train-map@5:0.74434	train-ndcg@5:0.76784
# [36]	train-map@5:0.74430	train-ndcg@5:0.76780
# [37]	train-map@5:0.74505	train-ndcg@5:0.76849
# [38]	train-map@5:0.74545	train-ndcg@5:0.76881
# [39]	train-map@5:0.74549	train-ndcg@5:0.76863
# [40]	train-map@5:0.74555	train-ndcg@5:0.76865
# [41]	train-map@5:0.74543	train-ndcg@5:0.76877
# [42]	train-map@5:0.74566	train-ndcg@5:0.76897
# [43]	train-map@5:0.74555	train-ndcg@5:0.76888
# [44]	train-map@5:0.74573	train-ndcg@5:0.76906
# [45]	train-map@5:0.74548	train-ndcg@5:0.76885
# [46]	train-map@5:0.74612	train-ndcg@5:0.76949
# [47]	train-map@5:0.74632	train-ndcg@5:0.76974
# [48]	train-map@5:0.74620	train-ndcg@5:0.76946
# [49]	train-map@5:0.74643	train-ndcg@5:0.76978
# [50]	train-map@5:0.74654	train-ndcg@5:0.76982
# [51]	train-map@5:0.74673	train-ndcg@5:0.77002
# [52]	train-map@5:0.74685	train-ndcg@5:0.77012
# [53]	train-map@5:0.74714	train-ndcg@5:0.77042
# [54]	train-map@5:0.74699	train-ndcg@5:0.77014
# [55]	train-map@5:0.74697	train-ndcg@5:0.77011
# [56]	train-map@5:0.74713	train-ndcg@5:0.77025
# [57]	train-map@5:0.74735	train-ndcg@5:0.77046
# [58]	train-map@5:0.74775	train-ndcg@5:0.77093
# [59]	train-map@5:0.74804	train-ndcg@5:0.77109
# [60]	train-map@5:0.74802	train-ndcg@5:0.77112
# [61]	train-map@5:0.74806	train-ndcg@5:0.77114
# [62]	train-map@5:0.74790	train-ndcg@5:0.77098
# [63]	train-map@5:0.74763	train-ndcg@5:0.77073
# [64]	train-map@5:0.74752	train-ndcg@5:0.77065
# [65]	train-map@5:0.74759	train-ndcg@5:0.77075
# [66]	train-map@5:0.74766	train-ndcg@5:0.77086
# [67]	train-map@5:0.74804	train-ndcg@5:0.77114
# [68]	train-map@5:0.74845	train-ndcg@5:0.77152
# [69]	train-map@5:0.74843	train-ndcg@5:0.77138
# [70]	train-map@5:0.74841	train-ndcg@5:0.77156
# [71]	train-map@5:0.74841	train-ndcg@5:0.77161
# [72]	train-map@5:0.74835	train-ndcg@5:0.77152
# [73]	train-map@5:0.74869	train-ndcg@5:0.77181
# [74]	train-map@5:0.74886	train-ndcg@5:0.77204
# [75]	train-map@5:0.74900	train-ndcg@5:0.77228
# [76]	train-map@5:0.74917	train-ndcg@5:0.77241
# [77]	train-map@5:0.74906	train-ndcg@5:0.77222
# [78]	train-map@5:0.74896	train-ndcg@5:0.77214
# [79]	train-map@5:0.74888	train-ndcg@5:0.77208
# [80]	train-map@5:0.74869	train-ndcg@5:0.77189
# [81]	train-map@5:0.74856	train-ndcg@5:0.77185
# [82]	train-map@5:0.74879	train-ndcg@5:0.77201
# [83]	train-map@5:0.74897	train-ndcg@5:0.77201
# [84]	train-map@5:0.74907	train-ndcg@5:0.77213
# [85]	train-map@5:0.74903	train-ndcg@5:0.77213
# [86]	train-map@5:0.74910	train-ndcg@5:0.77222
# [87]	train-map@5:0.74913	train-ndcg@5:0.77225
# [88]	train-map@5:0.74946	train-ndcg@5:0.77249
# [89]	train-map@5:0.74920	train-ndcg@5:0.77222
# [90]	train-map@5:0.74947	train-ndcg@5:0.77245
# [91]	train-map@5:0.74975	train-ndcg@5:0.77266
# [92]	train-map@5:0.74968	train-ndcg@5:0.77262
# [93]	train-map@5:0.74994	train-ndcg@5:0.77285
# [94]	train-map@5:0.75030	train-ndcg@5:0.77316
# [95]	train-map@5:0.75062	train-ndcg@5:0.77349
# [96]	train-map@5:0.75033	train-ndcg@5:0.77334
# [97]	train-map@5:0.75039	train-ndcg@5:0.77330
# [98]	train-map@5:0.75037	train-ndcg@5:0.77333
# [99]	train-map@5:0.75060	train-ndcg@5:0.77355
# [100]	train-map@5:0.75057	train-ndcg@5:0.77358
# [101]	train-map@5:0.75041	train-ndcg@5:0.77348
# [102]	train-map@5:0.75069	train-ndcg@5:0.77371
# [103]	train-map@5:0.75096	train-ndcg@5:0.77392
# [104]	train-map@5:0.75078	train-ndcg@5:0.77371
# [105]	train-map@5:0.75096	train-ndcg@5:0.77384
# [106]	train-map@5:0.75088	train-ndcg@5:0.77371
# [107]	train-map@5:0.75109	train-ndcg@5:0.77390
# [108]	train-map@5:0.75103	train-ndcg@5:0.77385
# [109]	train-map@5:0.75107	train-ndcg@5:0.77394
# [110]	train-map@5:0.75111	train-ndcg@5:0.77400
# [111]	train-map@5:0.75127	train-ndcg@5:0.77412
# [112]	train-map@5:0.75118	train-ndcg@5:0.77418
# [113]	train-map@5:0.75133	train-ndcg@5:0.77425
# [114]	train-map@5:0.75151	train-ndcg@5:0.77442
# [115]	train-map@5:0.75156	train-ndcg@5:0.77442
# [116]	train-map@5:0.75163	train-ndcg@5:0.77447
# [117]	train-map@5:0.75159	train-ndcg@5:0.77448
# [118]	train-map@5:0.75167	train-ndcg@5:0.77462
# [119]	train-map@5:0.75186	train-ndcg@5:0.77471
# [120]	train-map@5:0.75178	train-ndcg@5:0.77471
# [121]	train-map@5:0.75195	train-ndcg@5:0.77488
# [122]	train-map@5:0.75191	train-ndcg@5:0.77496
# [123]	train-map@5:0.75206	train-ndcg@5:0.77500
# [124]	train-map@5:0.75216	train-ndcg@5:0.77505
# [125]	train-map@5:0.75228	train-ndcg@5:0.77516
# [126]	train-map@5:0.75213	train-ndcg@5:0.77504
# [127]	train-map@5:0.75211	train-ndcg@5:0.77496
# [128]	train-map@5:0.75242	train-ndcg@5:0.77526
# [129]	train-map@5:0.75258	train-ndcg@5:0.77538
# [130]	train-map@5:0.75272	train-ndcg@5:0.77551
# [131]	train-map@5:0.75275	train-ndcg@5:0.77553
# [132]	train-map@5:0.75275	train-ndcg@5:0.77556
# [133]	train-map@5:0.75313	train-ndcg@5:0.77584
# [134]	train-map@5:0.75316	train-ndcg@5:0.77596
# [135]	train-map@5:0.75321	train-ndcg@5:0.77599
# [136]	train-map@5:0.75348	train-ndcg@5:0.77622
# [137]	train-map@5:0.75348	train-ndcg@5:0.77622
# [138]	train-map@5:0.75336	train-ndcg@5:0.77616
# [139]	train-map@5:0.75343	train-ndcg@5:0.77614
# [140]	train-map@5:0.75352	train-ndcg@5:0.77635
# [141]	train-map@5:0.75359	train-ndcg@5:0.77629
# [142]	train-map@5:0.75352	train-ndcg@5:0.77623
# [143]	train-map@5:0.75333	train-ndcg@5:0.77616
# [144]	train-map@5:0.75345	train-ndcg@5:0.77630
# [145]	train-map@5:0.75359	train-ndcg@5:0.77642
# [146]	train-map@5:0.75373	train-ndcg@5:0.77650
# [147]	train-map@5:0.75400	train-ndcg@5:0.77680
# [148]	train-map@5:0.75405	train-ndcg@5:0.77679
# [149]	train-map@5:0.75407	train-ndcg@5:0.77680
# [150]	train-map@5:0.75414	train-ndcg@5:0.77693
# [151]	train-map@5:0.75398	train-ndcg@5:0.77681
# [152]	train-map@5:0.75403	train-ndcg@5:0.77677
# [153]	train-map@5:0.75396	train-ndcg@5:0.77672
# [154]	train-map@5:0.75412	train-ndcg@5:0.77691
# [155]	train-map@5:0.75409	train-ndcg@5:0.77689
# [156]	train-map@5:0.75415	train-ndcg@5:0.77704
# [157]	train-map@5:0.75427	train-ndcg@5:0.77704
# [158]	train-map@5:0.75416	train-ndcg@5:0.77694
# [159]	train-map@5:0.75426	train-ndcg@5:0.77706
# [160]	train-map@5:0.75448	train-ndcg@5:0.77723
# [161]	train-map@5:0.75433	train-ndcg@5:0.77707
# [162]	train-map@5:0.75461	train-ndcg@5:0.77731
# [163]	train-map@5:0.75468	train-ndcg@5:0.77738
# [164]	train-map@5:0.75480	train-ndcg@5:0.77748
# [165]	train-map@5:0.75487	train-ndcg@5:0.77751
# [166]	train-map@5:0.75478	train-ndcg@5:0.77753
# [167]	train-map@5:0.75475	train-ndcg@5:0.77751
# [168]	train-map@5:0.75477	train-ndcg@5:0.77751
# [169]	train-map@5:0.75492	train-ndcg@5:0.77768
# [170]	train-map@5:0.75504	train-ndcg@5:0.77777
# [171]	train-map@5:0.75487	train-ndcg@5:0.77767
# [172]	train-map@5:0.75488	train-ndcg@5:0.77768
# [173]	train-map@5:0.75497	train-ndcg@5:0.77777
# [174]	train-map@5:0.75512	train-ndcg@5:0.77786
# [175]	train-map@5:0.75502	train-ndcg@5:0.77772
# [176]	train-map@5:0.75526	train-ndcg@5:0.77798
# [177]	train-map@5:0.75543	train-ndcg@5:0.77802
# [178]	train-map@5:0.75563	train-ndcg@5:0.77824
# [179]	train-map@5:0.75556	train-ndcg@5:0.77819
# [180]	train-map@5:0.75570	train-ndcg@5:0.77832
# [181]	train-map@5:0.75583	train-ndcg@5:0.77841
# [182]	train-map@5:0.75592	train-ndcg@5:0.77852
# [183]	train-map@5:0.75580	train-ndcg@5:0.77841
# [184]	train-map@5:0.75580	train-ndcg@5:0.77832
# [185]	train-map@5:0.75585	train-ndcg@5:0.77836
# [186]	train-map@5:0.75575	train-ndcg@5:0.77829
# [187]	train-map@5:0.75581	train-ndcg@5:0.77838
# [188]	train-map@5:0.75587	train-ndcg@5:0.77845
# [189]	train-map@5:0.75585	train-ndcg@5:0.77839
# [190]	train-map@5:0.75593	train-ndcg@5:0.77847
# [191]	train-map@5:0.75583	train-ndcg@5:0.77849
# [192]	train-map@5:0.75606	train-ndcg@5:0.77861
# [193]	train-map@5:0.75597	train-ndcg@5:0.77848
# [194]	train-map@5:0.75622	train-ndcg@5:0.77871
# [195]	train-map@5:0.75609	train-ndcg@5:0.77862
# [196]	train-map@5:0.75624	train-ndcg@5:0.77875
# [197]	train-map@5:0.75639	train-ndcg@5:0.77880
# [198]	train-map@5:0.75611	train-ndcg@5:0.77854
# [199]	train-map@5:0.75621	train-ndcg@5:0.77869
# [200]	train-map@5:0.75614	train-ndcg@5:0.77868
# [201]	train-map@5:0.75638	train-ndcg@5:0.77884
# [202]	train-map@5:0.75634	train-ndcg@5:0.77880
# [203]	train-map@5:0.75629	train-ndcg@5:0.77884
# [204]	train-map@5:0.75637	train-ndcg@5:0.77889
# [205]	train-map@5:0.75628	train-ndcg@5:0.77881
# [206]	train-map@5:0.75673	train-ndcg@5:0.77915
# [207]	train-map@5:0.75654	train-ndcg@5:0.77896
# [208]	train-map@5:0.75657	train-ndcg@5:0.77901
# [209]	train-map@5:0.75663	train-ndcg@5:0.77905
# [210]	train-map@5:0.75688	train-ndcg@5:0.77928
# [211]	train-map@5:0.75662	train-ndcg@5:0.77909
# [212]	train-map@5:0.75668	train-ndcg@5:0.77913
# [213]	train-map@5:0.75684	train-ndcg@5:0.77930
# [214]	train-map@5:0.75696	train-ndcg@5:0.77937
# [215]	train-map@5:0.75692	train-ndcg@5:0.77936
# [216]	train-map@5:0.75718	train-ndcg@5:0.77958
# [217]	train-map@5:0.75731	train-ndcg@5:0.77970
# [218]	train-map@5:0.75735	train-ndcg@5:0.77971
# [219]	train-map@5:0.75745	train-ndcg@5:0.77976
# [220]	train-map@5:0.75739	train-ndcg@5:0.77973
# [221]	train-map@5:0.75750	train-ndcg@5:0.77979
# [222]	train-map@5:0.75757	train-ndcg@5:0.77985
# [223]	train-map@5:0.75749	train-ndcg@5:0.77977
# [224]	train-map@5:0.75761	train-ndcg@5:0.77990
# [225]	train-map@5:0.75762	train-ndcg@5:0.77991
# [226]	train-map@5:0.75752	train-ndcg@5:0.77986
# [227]	train-map@5:0.75753	train-ndcg@5:0.77985
# [228]	train-map@5:0.75760	train-ndcg@5:0.77992
# [229]	train-map@5:0.75764	train-ndcg@5:0.77998
# [230]	train-map@5:0.75766	train-ndcg@5:0.77999
# [231]	train-map@5:0.75763	train-ndcg@5:0.77994
# [232]	train-map@5:0.75777	train-ndcg@5:0.78005
# [233]	train-map@5:0.75783	train-ndcg@5:0.78012
# [234]	train-map@5:0.75801	train-ndcg@5:0.78028
# [235]	train-map@5:0.75824	train-ndcg@5:0.78045
# [236]	train-map@5:0.75817	train-ndcg@5:0.78040
# [237]	train-map@5:0.75823	train-ndcg@5:0.78044
# [238]	train-map@5:0.75823	train-ndcg@5:0.78044
# [239]	train-map@5:0.75815	train-ndcg@5:0.78039
# [240]	train-map@5:0.75827	train-ndcg@5:0.78055
# [241]	train-map@5:0.75830	train-ndcg@5:0.78055
# [242]	train-map@5:0.75845	train-ndcg@5:0.78073
# [243]	train-map@5:0.75853	train-ndcg@5:0.78081
# [244]	train-map@5:0.75845	train-ndcg@5:0.78073
# [245]	train-map@5:0.75846	train-ndcg@5:0.78076
# [246]	train-map@5:0.75836	train-ndcg@5:0.78066
# [247]	train-map@5:0.75862	train-ndcg@5:0.78095
# [248]	train-map@5:0.75875	train-ndcg@5:0.78108
# [249]	train-map@5:0.75875	train-ndcg@5:0.78105
# [250]	train-map@5:0.75914	train-ndcg@5:0.78131
# [251]	train-map@5:0.75883	train-ndcg@5:0.78103
# [252]	train-map@5:0.75896	train-ndcg@5:0.78116
# [253]	train-map@5:0.75890	train-ndcg@5:0.78114
# [254]	train-map@5:0.75876	train-ndcg@5:0.78103
# [255]	train-map@5:0.75899	train-ndcg@5:0.78120
# [256]	train-map@5:0.75888	train-ndcg@5:0.78110
# [257]	train-map@5:0.75884	train-ndcg@5:0.78107
# [258]	train-map@5:0.75903	train-ndcg@5:0.78119
# [259]	train-map@5:0.75910	train-ndcg@5:0.78124
# [260]	train-map@5:0.75925	train-ndcg@5:0.78140
# [261]	train-map@5:0.75924	train-ndcg@5:0.78136
# [262]	train-map@5:0.75931	train-ndcg@5:0.78142
# [263]	train-map@5:0.75935	train-ndcg@5:0.78145
# [264]	train-map@5:0.75944	train-ndcg@5:0.78156
# [265]	train-map@5:0.75940	train-ndcg@5:0.78151
# [266]	train-map@5:0.75963	train-ndcg@5:0.78171
# [267]	train-map@5:0.75958	train-ndcg@5:0.78165
# [268]	train-map@5:0.75949	train-ndcg@5:0.78161
# [269]	train-map@5:0.75954	train-ndcg@5:0.78169
# [270]	train-map@5:0.75967	train-ndcg@5:0.78184
# [271]	train-map@5:0.75989	train-ndcg@5:0.78205
# [272]	train-map@5:0.75982	train-ndcg@5:0.78197
# [273]	train-map@5:0.76012	train-ndcg@5:0.78224
# [274]	train-map@5:0.76010	train-ndcg@5:0.78223
# [275]	train-map@5:0.76021	train-ndcg@5:0.78230
# [276]	train-map@5:0.76023	train-ndcg@5:0.78235
# [277]	train-map@5:0.76024	train-ndcg@5:0.78240
# [278]	train-map@5:0.76037	train-ndcg@5:0.78257
# [279]	train-map@5:0.76051	train-ndcg@5:0.78263
# [280]	train-map@5:0.76054	train-ndcg@5:0.78264
# [281]	train-map@5:0.76062	train-ndcg@5:0.78273
# [282]	train-map@5:0.76075	train-ndcg@5:0.78285
# [283]	train-map@5:0.76048	train-ndcg@5:0.78256
# [284]	train-map@5:0.76065	train-ndcg@5:0.78271
# [285]	train-map@5:0.76075	train-ndcg@5:0.78281
# [286]	train-map@5:0.76073	train-ndcg@5:0.78279
# [287]	train-map@5:0.76077	train-ndcg@5:0.78284
# [288]	train-map@5:0.76074	train-ndcg@5:0.78280
# [289]	train-map@5:0.76076	train-ndcg@5:0.78281
# [290]	train-map@5:0.76087	train-ndcg@5:0.78290
# [291]	train-map@5:0.76082	train-ndcg@5:0.78286
# [292]	train-map@5:0.76084	train-ndcg@5:0.78283
# [293]	train-map@5:0.76097	train-ndcg@5:0.78295
# [294]	train-map@5:0.76105	train-ndcg@5:0.78310
# [295]	train-map@5:0.76099	train-ndcg@5:0.78305
# [296]	train-map@5:0.76100	train-ndcg@5:0.78304
# [297]	train-map@5:0.76088	train-ndcg@5:0.78293
# [298]	train-map@5:0.76104	train-ndcg@5:0.78305
# [299]	train-map@5:0.76087	train-ndcg@5:0.78292
# [300]	train-map@5:0.76100	train-ndcg@5:0.78299
# [301]	train-map@5:0.76107	train-ndcg@5:0.78307
# [302]	train-map@5:0.76114	train-ndcg@5:0.78313
# [303]	train-map@5:0.76104	train-ndcg@5:0.78305
# [304]	train-map@5:0.76109	train-ndcg@5:0.78309
# [305]	train-map@5:0.76131	train-ndcg@5:0.78332
# [306]	train-map@5:0.76141	train-ndcg@5:0.78347
# [307]	train-map@5:0.76147	train-ndcg@5:0.78346
# [308]	train-map@5:0.76150	train-ndcg@5:0.78346
# [309]	train-map@5:0.76155	train-ndcg@5:0.78350
# [310]	train-map@5:0.76181	train-ndcg@5:0.78376
# [311]	train-map@5:0.76193	train-ndcg@5:0.78383
# [312]	train-map@5:0.76193	train-ndcg@5:0.78383
# [313]	train-map@5:0.76170	train-ndcg@5:0.78371
# [314]	train-map@5:0.76190	train-ndcg@5:0.78384
# [315]	train-map@5:0.76174	train-ndcg@5:0.78374
# [316]	train-map@5:0.76173	train-ndcg@5:0.78369
# [317]	train-map@5:0.76184	train-ndcg@5:0.78380
# [318]	train-map@5:0.76205	train-ndcg@5:0.78395
# [319]	train-map@5:0.76213	train-ndcg@5:0.78399
# [320]	train-map@5:0.76220	train-ndcg@5:0.78411
# [321]	train-map@5:0.76229	train-ndcg@5:0.78420
# [322]	train-map@5:0.76228	train-ndcg@5:0.78415
# [323]	train-map@5:0.76235	train-ndcg@5:0.78423
# [324]	train-map@5:0.76234	train-ndcg@5:0.78419
# [325]	train-map@5:0.76244	train-ndcg@5:0.78426
# [326]	train-map@5:0.76231	train-ndcg@5:0.78414
# [327]	train-map@5:0.76228	train-ndcg@5:0.78414
# [328]	train-map@5:0.76232	train-ndcg@5:0.78417
# [329]	train-map@5:0.76231	train-ndcg@5:0.78419
# [330]	train-map@5:0.76234	train-ndcg@5:0.78421
# [331]	train-map@5:0.76243	train-ndcg@5:0.78430
# [332]	train-map@5:0.76250	train-ndcg@5:0.78440
# [333]	train-map@5:0.76260	train-ndcg@5:0.78450
# [334]	train-map@5:0.76270	train-ndcg@5:0.78458
# [335]	train-map@5:0.76268	train-ndcg@5:0.78456
# [336]	train-map@5:0.76261	train-ndcg@5:0.78453
# [337]	train-map@5:0.76253	train-ndcg@5:0.78445
# [338]	train-map@5:0.76245	train-ndcg@5:0.78435
# [339]	train-map@5:0.76250	train-ndcg@5:0.78448
# [340]	train-map@5:0.76240	train-ndcg@5:0.78435
# [341]	train-map@5:0.76241	train-ndcg@5:0.78439
# [342]	train-map@5:0.76234	train-ndcg@5:0.78429
# [343]	train-map@5:0.76247	train-ndcg@5:0.78439
# [344]	train-map@5:0.76269	train-ndcg@5:0.78462
# [345]	train-map@5:0.76272	train-ndcg@5:0.78464
# [346]	train-map@5:0.76269	train-ndcg@5:0.78462
# [347]	train-map@5:0.76272	train-ndcg@5:0.78463
# [348]	train-map@5:0.76280	train-ndcg@5:0.78468
# [349]	train-map@5:0.76284	train-ndcg@5:0.78467
# [350]	train-map@5:0.76307	train-ndcg@5:0.78484
# [351]	train-map@5:0.76295	train-ndcg@5:0.78473
# [352]	train-map@5:0.76314	train-ndcg@5:0.78489
# [353]	train-map@5:0.76326	train-ndcg@5:0.78510
# [354]	train-map@5:0.76334	train-ndcg@5:0.78515
# [355]	train-map@5:0.76332	train-ndcg@5:0.78514
# [356]	train-map@5:0.76325	train-ndcg@5:0.78507
# [357]	train-map@5:0.76328	train-ndcg@5:0.78505
# [358]	train-map@5:0.76342	train-ndcg@5:0.78512
# [359]	train-map@5:0.76338	train-ndcg@5:0.78507
# [360]	train-map@5:0.76347	train-ndcg@5:0.78515
# [361]	train-map@5:0.76348	train-ndcg@5:0.78517
# [362]	train-map@5:0.76350	train-ndcg@5:0.78521
# [363]	train-map@5:0.76360	train-ndcg@5:0.78529
# [364]	train-map@5:0.76355	train-ndcg@5:0.78527
# [365]	train-map@5:0.76352	train-ndcg@5:0.78520
# [366]	train-map@5:0.76354	train-ndcg@5:0.78522
# [367]	train-map@5:0.76369	train-ndcg@5:0.78533
# [368]	train-map@5:0.76372	train-ndcg@5:0.78538
# [369]	train-map@5:0.76378	train-ndcg@5:0.78540
# [370]	train-map@5:0.76386	train-ndcg@5:0.78548
# [371]	train-map@5:0.76395	train-ndcg@5:0.78551
# [372]	train-map@5:0.76404	train-ndcg@5:0.78566
# [373]	train-map@5:0.76403	train-ndcg@5:0.78568
# [374]	train-map@5:0.76424	train-ndcg@5:0.78591
# [375]	train-map@5:0.76412	train-ndcg@5:0.78575
# [376]	train-map@5:0.76416	train-ndcg@5:0.78581
# [377]	train-map@5:0.76423	train-ndcg@5:0.78583
# [378]	train-map@5:0.76433	train-ndcg@5:0.78593
# [379]	train-map@5:0.76439	train-ndcg@5:0.78599
# [380]	train-map@5:0.76450	train-ndcg@5:0.78605
# [381]	train-map@5:0.76451	train-ndcg@5:0.78606
# [382]	train-map@5:0.76450	train-ndcg@5:0.78605
# [383]	train-map@5:0.76455	train-ndcg@5:0.78609
# [384]	train-map@5:0.76447	train-ndcg@5:0.78604
# [385]	train-map@5:0.76448	train-ndcg@5:0.78607
# [386]	train-map@5:0.76469	train-ndcg@5:0.78622
# [387]	train-map@5:0.76477	train-ndcg@5:0.78633
# [388]	train-map@5:0.76491	train-ndcg@5:0.78643
# [389]	train-map@5:0.76490	train-ndcg@5:0.78643
# [390]	train-map@5:0.76495	train-ndcg@5:0.78649
# [391]	train-map@5:0.76488	train-ndcg@5:0.78643
# [392]	train-map@5:0.76501	train-ndcg@5:0.78651
# [393]	train-map@5:0.76499	train-ndcg@5:0.78646
# [394]	train-map@5:0.76504	train-ndcg@5:0.78649
# [395]	train-map@5:0.76499	train-ndcg@5:0.78648
# [396]	train-map@5:0.76511	train-ndcg@5:0.78657
# [397]	train-map@5:0.76512	train-ndcg@5:0.78658
# [398]	train-map@5:0.76518	train-ndcg@5:0.78660
# [399]	train-map@5:0.76526	train-ndcg@5:0.78671
# [400]	train-map@5:0.76524	train-ndcg@5:0.78667
# [401]	train-map@5:0.76535	train-ndcg@5:0.78678
# [402]	train-map@5:0.76533	train-ndcg@5:0.78679
# [403]	train-map@5:0.76540	train-ndcg@5:0.78686
# [404]	train-map@5:0.76532	train-ndcg@5:0.78682
# [405]	train-map@5:0.76536	train-ndcg@5:0.78688
# [406]	train-map@5:0.76537	train-ndcg@5:0.78690
# [407]	train-map@5:0.76543	train-ndcg@5:0.78700
# [408]	train-map@5:0.76539	train-ndcg@5:0.78695
# [409]	train-map@5:0.76539	train-ndcg@5:0.78695
# [410]	train-map@5:0.76547	train-ndcg@5:0.78705
# [411]	train-map@5:0.76545	train-ndcg@5:0.78702
# [412]	train-map@5:0.76544	train-ndcg@5:0.78703
# [413]	train-map@5:0.76557	train-ndcg@5:0.78711
# [414]	train-map@5:0.76574	train-ndcg@5:0.78726
# [415]	train-map@5:0.76571	train-ndcg@5:0.78723
# [416]	train-map@5:0.76571	train-ndcg@5:0.78723
# [417]	train-map@5:0.76582	train-ndcg@5:0.78734
# [418]	train-map@5:0.76595	train-ndcg@5:0.78746
# [419]	train-map@5:0.76608	train-ndcg@5:0.78755
# [420]	train-map@5:0.76620	train-ndcg@5:0.78764
# [421]	train-map@5:0.76621	train-ndcg@5:0.78765
# [422]	train-map@5:0.76628	train-ndcg@5:0.78772
# [423]	train-map@5:0.76627	train-ndcg@5:0.78769
# [424]	train-map@5:0.76624	train-ndcg@5:0.78767
# [425]	train-map@5:0.76610	train-ndcg@5:0.78760
# [426]	train-map@5:0.76629	train-ndcg@5:0.78779
# [427]	train-map@5:0.76629	train-ndcg@5:0.78779
# [428]	train-map@5:0.76632	train-ndcg@5:0.78783
# [429]	train-map@5:0.76617	train-ndcg@5:0.78767
# [430]	train-map@5:0.76637	train-ndcg@5:0.78789
# [431]	train-map@5:0.76641	train-ndcg@5:0.78795
# [432]	train-map@5:0.76650	train-ndcg@5:0.78801
# [433]	train-map@5:0.76645	train-ndcg@5:0.78795
# [434]	train-map@5:0.76627	train-ndcg@5:0.78780
# [435]	train-map@5:0.76657	train-ndcg@5:0.78805
# [436]	train-map@5:0.76661	train-ndcg@5:0.78808
# [437]	train-map@5:0.76665	train-ndcg@5:0.78813
# [438]	train-map@5:0.76671	train-ndcg@5:0.78820
# [439]	train-map@5:0.76663	train-ndcg@5:0.78812
# [440]	train-map@5:0.76673	train-ndcg@5:0.78817
# [441]	train-map@5:0.76690	train-ndcg@5:0.78834
# [442]	train-map@5:0.76682	train-ndcg@5:0.78828
# [443]	train-map@5:0.76681	train-ndcg@5:0.78828
# [444]	train-map@5:0.76670	train-ndcg@5:0.78815
# [445]	train-map@5:0.76698	train-ndcg@5:0.78845
# [446]	train-map@5:0.76698	train-ndcg@5:0.78845
# [447]	train-map@5:0.76706	train-ndcg@5:0.78846
# [448]	train-map@5:0.76710	train-ndcg@5:0.78854
# [449]	train-map@5:0.76718	train-ndcg@5:0.78860
# [450]	train-map@5:0.76716	train-ndcg@5:0.78861
# [451]	train-map@5:0.76723	train-ndcg@5:0.78870
# [452]	train-map@5:0.76723	train-ndcg@5:0.78869
# [453]	train-map@5:0.76728	train-ndcg@5:0.78877
# [454]	train-map@5:0.76724	train-ndcg@5:0.78869
# [455]	train-map@5:0.76732	train-ndcg@5:0.78880
# [456]	train-map@5:0.76726	train-ndcg@5:0.78871
# [457]	train-map@5:0.76755	train-ndcg@5:0.78900
# [458]	train-map@5:0.76751	train-ndcg@5:0.78896
# [459]	train-map@5:0.76743	train-ndcg@5:0.78891
# [460]	train-map@5:0.76761	train-ndcg@5:0.78904
# [461]	train-map@5:0.76755	train-ndcg@5:0.78900
# [462]	train-map@5:0.76775	train-ndcg@5:0.78912
# [463]	train-map@5:0.76780	train-ndcg@5:0.78918
# [464]	train-map@5:0.76776	train-ndcg@5:0.78915
# [465]	train-map@5:0.76783	train-ndcg@5:0.78918
# [466]	train-map@5:0.76797	train-ndcg@5:0.78933
# [467]	train-map@5:0.76806	train-ndcg@5:0.78944
# [468]	train-map@5:0.76811	train-ndcg@5:0.78949
# [469]	train-map@5:0.76799	train-ndcg@5:0.78935
# [470]	train-map@5:0.76801	train-ndcg@5:0.78932
# [471]	train-map@5:0.76799	train-ndcg@5:0.78933
# [472]	train-map@5:0.76800	train-ndcg@5:0.78935
# [473]	train-map@5:0.76802	train-ndcg@5:0.78939
# [474]	train-map@5:0.76809	train-ndcg@5:0.78947
# [475]	train-map@5:0.76815	train-ndcg@5:0.78952
# [476]	train-map@5:0.76812	train-ndcg@5:0.78945
# [477]	train-map@5:0.76820	train-ndcg@5:0.78953
# [478]	train-map@5:0.76821	train-ndcg@5:0.78949
# [479]	train-map@5:0.76823	train-ndcg@5:0.78951
# [480]	train-map@5:0.76851	train-ndcg@5:0.78974
# [481]	train-map@5:0.76851	train-ndcg@5:0.78972
# [482]	train-map@5:0.76856	train-ndcg@5:0.78976
# [483]	train-map@5:0.76845	train-ndcg@5:0.78961
# [484]	train-map@5:0.76849	train-ndcg@5:0.78968
# [485]	train-map@5:0.76848	train-ndcg@5:0.78965
# [486]	train-map@5:0.76850	train-ndcg@5:0.78967
# [487]	train-map@5:0.76846	train-ndcg@5:0.78964
# [488]	train-map@5:0.76858	train-ndcg@5:0.78978
# [489]	train-map@5:0.76853	train-ndcg@5:0.78973
# [490]	train-map@5:0.76862	train-ndcg@5:0.78983
# [491]	train-map@5:0.76869	train-ndcg@5:0.78995
# [492]	train-map@5:0.76864	train-ndcg@5:0.78985
# [493]	train-map@5:0.76856	train-ndcg@5:0.78971
# [494]	train-map@5:0.76864	train-ndcg@5:0.78984
# [495]	train-map@5:0.76874	train-ndcg@5:0.78998
# [496]	train-map@5:0.76861	train-ndcg@5:0.78984
# [497]	train-map@5:0.76862	train-ndcg@5:0.78988
# [498]	train-map@5:0.76860	train-ndcg@5:0.78986
# [499]	train-map@5:0.76874	train-ndcg@5:0.79001
#
# Feature Importance:
# f0: 487.0022
# f3: 89.3573
# f1: 36.4904
# f2: 21.7450
# f4: 11.5527
# f5: 8.4758
# f6: 7.7138
#
# Validation MRR@5: 0.7262
#
# Validation Statistics:
# Total validation queries: 2571
# Queries with relevant documents: 2532
# Average relevant documents per query: 0.98
